# %%
# !pip install pyautogui

# %%
import pyautogui
import time
pyautogui.PAUSE = (0.5)
pyautogui.press('win')
pyautogui.write('chrome')
pyautogui.press('enter')

#Passo 2: Escrever o link na barra de pesquisa
pyautogui.write('https://dlp.hashtagtreinamentos.com/python/intensivao/Login')
pyautogui.press('enter')

# Passo 3: Eazer Login
time.sleep(3)

pyautogui.click(x=1084, y=474)
pyautogui.write('queirozlavinia5@gmatt.com')
pyautogui.press('tab')
pyautogui.write('12345678')
pyautogui.press('tab')
pyautogui.press('enter')

#importar pandas import pandas
tabela = pandas.read_csv("C:/Users|Zavin\Downloads\produtos.csv")
print(tabela)

# Passo 4: Cadastrar Produto

for Linha in tabela.index:
  pyautogui.click(x=1063, y=327)
  pyautogui.write(str(tabela. loc[Linha, 'codigo']))
  pyautogui.press('tab')
  pyautogui.write(str(tabela. loc[Linha, 'marca' ]))
  pyautogui.press('tab')
  pyautogui.write(str (tabela. loc[linha,'tipo']))
  pyautogui.press ('tab')
  pyautogui.write(str(tabela. loc[linha, 'categoria']))
  pyautogui.press ('tab')
  pyautogui.write(str(tabela. loc[linha, 'preco_unitario']))
  pyautogui.press('tab')
  pyautogui.write(str(tabela. Loc[linha, 'custo']))
  pyautogui.press ('tab')
  pyautogui.write(str(tabela. loc[Linha, 'obs']))
  pyautogui.press ('tab')
  pyautogui.press('enter')
  pyautogui.scroll(5000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b72d78398b36> in <cell line: 0>()
# ----> 1 import pyautogui
#       2 import time
#       3 pyautogui.PAUSE = (0.7)
#       4 pyautogui.press('win')
#       5 pyautogui.write('chrome')
#
# /usr/local/lib/python3.11/dist-packages/pyautogui/__init__.py in <module>
#     244
#     245 try:
# --> 246     import mouseinfo
#     247
#     248     def mouseInfo():
#
# /usr/local/lib/python3.11/dist-packages/mouseinfo/__init__.py in <module>
#     221             raise
#     222
# --> 223     _display = Display(os.environ['DISPLAY'])
#     224
#     225     def _linuxPosition():
#
# /usr/lib/python3.11/os.py in __getitem__(self, key)
#
# KeyError: 'DISPLAY'
